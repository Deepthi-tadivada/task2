# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc

# %%
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-7A07QL7\\MSSQLSERVER1;'
    'UID=sa;'
    'PWD=1234'
)

# %%
import pyodbc

# Connection to SQL Server
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-7A07QL7\\MSSQLSERVER1;'
    'DATABASE=master;'  # Using 'master' database to create a new database
    'UID=sa;'
    'PWD=1234;'
)

# Enable autocommit for database creation
conn.autocommit = True

# Cursor for SQL execution
cursor = conn.cursor()

# Database name
database_name = "ETL2"

# SQL query to create a database
create_db_query = f"CREATE DATABASE {database_name}"

# Execute SQL
try:
    cursor.execute(create_db_query)
    print(f"Database '{database_name}' created successfully!")
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    # Close the connection
    conn.close()
# Out:
# Database 'ETL2' created successfully!

# %%
pip install pandas sqlalchemy pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# File path to your CSV file


# Step 1: Read the CSV file
df = pd.read_csv("us_customer_data1.csv")
df

# %%
import pandas as pd
from sqlalchemy import create_engine

# File path to your CSV file


# Step 1: Read the CSV file
df1 = pd.read_csv("cleaned_countrycodes.csv")
df1.dropna()
# Out:
#     country_code CallingCode
# 1             AF          93
# 2             AL         355
# 3             DZ         213
# 4             AD         376
# 5             AO         244
# ..           ...         ...
# 182           VE          58
# 183           VN          84
# 184           YE         967
# 185           ZM         260
# 186           ZW         263
#
# [185 rows x 2 columns]

# %%
# Step 2: Database connection using SQLAlchemy
engine = create_engine(
    "mssql+pyodbc://sa:1234@DESKTOP-7A07QL7\\MSSQLSERVER1/ETL2?driver=ODBC+Driver+17+for+SQL+Server"
)

# Step 3: Push the CSV data into the database table
# If the table does not exist, it will be created.
df.to_sql('Customers', con=engine, if_exists='replace', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
# Step 2: Database connection using SQLAlchemy
engine = create_engine(
    "mssql+pyodbc://sa:1234@DESKTOP-7A07QL7\\MSSQLSERVER1/ETL2?driver=ODBC+Driver+17+for+SQL+Server"
)

# Step 3: Push the CSV data into the database table
# If the table does not exist, it will be created.
df1.to_sql('cleaned_countrycodes', con=engine, if_exists='replace', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-7A07QL7\\MSSQLSERVER1;'
    'database_name=YourDatabaseName;'
    'UID=sa;'
    'PWD=1234'
)

# %%
cursor=conn.cursor()

# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=DESKTOP-7A07QL7\\MSSQLSERVER1;'
    'DATABASE=ETL2;'  # Ensure the correct database name
    'UID=sa;'
    'PWD=1234;'
)

# Correct the table name and schema
query = "SELECT * FROM dbo.Customers"  # Use the correct table name

# Fetch data into a DataFrame
df = pd.read_sql(query, conn)

print(df)
conn.close()
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.iloc[993]
# Out:
# customer_id                                                  994
# name                                                  Mario Odom
# email                                  sheilarobbins@example.org
# phone                                               773-566-3560
# address              87583 Tabitha Bypass, West Denise, LA 20244
# registration_date                                     24-03-2025
# loyalty_status                                            Silver
# Name: 993, dtype: object

# %%
df['name']=df['name'].str.replace(r'\s*(Jr\.|Sr\.|II|III|MD|DDS|PhD)$',"",regex=True)

# %%
df['name']=df['name'].str.replace(r'^(Mr\.|Mrs\.|Miss\.|Dr\.)\s*',"",regex=True)

# %%
df.loc[993]
# Out:
# customer_id                                                  994
# name                                                    ao Odom
# email                                  sheilarobbins@example.org
# phone                                               773-566-3560
# address              87583 Tabitha Bypass, West Denise, LA 20244
# registration_date                                     24-03-2025
# loyalty_status                                            Silver
# Name: 993, dtype: object

# %%
df.columns
# Out:
# Index(['customer_id', 'name', 'email', 'phone', 'address', 'registration_date',
#        'loyalty_status'],
#       dtype='object')

# %%
df['name'] = df['name'].astype(str)

# Step 2: Split the 'name' column into 'first_name' and 'last_name'
df[['first_name', 'last_name']] = df['name'].str.split(' ', n=1, expand=True)

# Step 3: Handle missing last_name values (optional)
df['last_name'] = df['last_name'].fillna('Unknown')

# Display the resulting DataFrame
print(df)

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df1.dropna()
# Out:
#     country_code CallingCode
# 1             AF          93
# 2             AL         355
# 3             DZ         213
# 4             AD         376
# 5             AO         244
# ..           ...         ...
# 182           VE          58
# 183           VN          84
# 184           YE         967
# 185           ZM         260
# 186           ZW         263
#
# [185 rows x 2 columns]

# %%
# Remove extra characters from the `phone` column
df['phone'] = df['phone'].str.replace(r'[^0-9]', '', regex=True)

# Display the updated DataFrame
print(df[['phone']].head())
# Out:
#         phone
# 0  6197234258
# 1  5376741158
# 2  8102564505
# 3  4232229779
# 4  2207633522

# %%
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# country_code    0
# CallingCode     0
# dtype: int64

# %%
df['country_code'] = df['address'].str.extract(r'\b([A-Z]{2})\b(?!.*\b[A-Z]{2}\b)')

# Replace nulls with a placeholder for manual verification
df['country_code'].fillna('UNKNOWN', inplace=True)
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 3              4    Kimberly Price    jessicaknight@example.com  4232229779
# 4              5  Matthew Phillips        qwilliams@example.com  2207633522
# ..           ...               ...                          ...         ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  6389899441
# 996          997      Jodi Simpson           eric24@example.org  4836252940
# 997          998     Crystal Brown         pshaffer@example.net  3907473088
# 998          999    Gregory Duarte    caitlindunlap@example.org  2574098196
# 999         1000       Jason Walls        michael42@example.com  6923336880
#
# ...

# %%
df.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# first_name           0
# last_name            0
# country_code         0
# dtype: int64

# %%
df['email']=df['email'].fillna('NO EMAIL')
df['phone']=df['phone'].fillna('Unknown Phone')

# %%
unified_model=pd.merge(df,df1,on='country_code',how='inner')

# %%
unified_model
# Out:
#      customer_id                   name                        email  \
# 0              1          Michelle Kidd           vayala@example.net
# 1              2            Brad Newton  taylorcatherine@example.net
# 2              4         Kimberly Price    jessicaknight@example.com
# 3              6  Darrell Gallagher DVM      larryharris@example.org
# 4             10           Rachel White     whitemichael@example.org
# ..           ...                    ...                          ...
# 411          992         Thomas Stevens    vargasmatthew@example.org
# 412          994             Mario Odom    sheilarobbins@example.org
# 413          997           Jodi Simpson           eric24@example.org
# 414          998          Crystal Brown         pshaffer@example.net
# 415         1000            Jason Walls        michael42@example.com
#
#           phone                                            address  \
# 0    6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
unified_model['phone']= '+' +unified_model['CallingCode']+' '+unified_model['phone']

# %%
unified_model

# %%
tier_mapping = {
    "Gold": 2,
    "Silver": 1,
    "Bronze": 0
}

# Add Customer_Tier column to unified model DataFrame
unified_model['Customer_Tier'] = unified_model['loyalty_status'].map(tier_mapping)

# Display updated DataFrame
print(unified_model)

# %%
unified_model.to_csv("unified_model",index=False)

# %%
server = 'DESKTOP-7A07QL7\\MSSQLSERVER1'  # Replace with your server name
database = 'ETL1'                         # Replace with your database name
username = 'sa'                           # Replace with your username
password = '1234'                         # Replace with your password

# Connection string for SQL Server
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"

# Create SQLAlchemy engine
engine = create_engine(connection_string)

# Send DataFrame to SQL
table_name = 'unified_model'  # Replace with your target table name
unified_model.to_sql(table_name, engine, if_exists='replace', index=False)

print(f"DataFrame successfully sent to SQL table '{table_name}' in database '{database}'.")

# %%
d=pd.read_csv('unified_model')
# Out:
#      customer_id                   name                        email  \
# 0              1          Michelle Kidd           vayala@example.net
# 1              2            Brad Newton  taylorcatherine@example.net
# 2              4         Kimberly Price    jessicaknight@example.com
# 3              6  Darrell Gallagher DVM      larryharris@example.org
# 4             10           Rachel White     whitemichael@example.org
# ..           ...                    ...                          ...
# 411          992         Thomas Stevens    vargasmatthew@example.org
# 412          994             Mario Odom    sheilarobbins@example.org
# 413          997           Jodi Simpson           eric24@example.org
# 414          998          Crystal Brown         pshaffer@example.net
# 415         1000            Jason Walls        michael42@example.com
#
#                phone                                            address  \
# ...

# %%
# Step 2: Database connection using SQLAlchemy
engine = create_engine(
    "mssql+pyodbc://sa:1234@DESKTOP-7A07QL7\\MSSQLSERVER1/ETL2?driver=ODBC+Driver+17+for+SQL+Server"
)

# Step 3: Push the CSV data into the database table
# If the table does not exist, it will be created.
d.to_sql('unified_model', con=engine, if_exists='replace', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
unified_model
# Out:
#      customer_id                   name                        email  \
# 0              1          Michelle Kidd           vayala@example.net
# 1              2            Brad Newton  taylorcatherine@example.net
# 2              4         Kimberly Price    jessicaknight@example.com
# 3              6  Darrell Gallagher DVM      larryharris@example.org
# 4             10           Rachel White     whitemichael@example.org
# ..           ...                    ...                          ...
# 411          992         Thomas Stevens    vargasmatthew@example.org
# 412          994             Mario Odom    sheilarobbins@example.org
# 413          997           Jodi Simpson           eric24@example.org
# 414          998          Crystal Brown         pshaffer@example.net
# 415         1000            Jason Walls        michael42@example.com
#
#                phone                                            address  \
# ...

# %%
# Filter emails ending with 'email.com'
filtered_emails = df[df['email'].str.endswith('@example.net', na=False)]
 
print(filtered_emails)
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 7              8  Melissa Galloway   watsonbenjamin@example.net  5485499586
# 8              9    Matthew Harvey          bgaines@example.net  5811447338
# ..           ...               ...                          ...         ...
# 981          982         Rose Rush        chenjames@example.net  9609943492
# 983          984  Crystal Ferguson        diazmegan@example.net  5433974748
# 990          991     Erica Fleming          erica85@example.net  6264536078
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  6389899441
# 997          998     Crystal Brown         pshaffer@example.net  3907473088
#
# ...
